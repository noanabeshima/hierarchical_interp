# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.distributions as dists
import numpy as np

from interp_utils import hist

beta_dist = dists.Beta(10, 9)

hist(beta_dist.sample((30000,)))
