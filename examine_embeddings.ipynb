# %%
from transformers import GPT2LMHeadModel
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch.distributions as dists
import numpy as np

# %%
from interp_utils import heatmap, reload_module

reload_module('gpt_embeds')
from gpt_embeds import embeds, toks, enc

tok_start = 4000
n_toks = 300
embeds_subset = embeds[tok_start:tok_start+n_toks]
toks_subset = toks[tok_start:tok_start+n_toks]

heatmap(embeds_subset @ embeds_subset.T, info_0={'tok': toks_subset}, info_1={'tok': toks_subset})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 from interp_utils import heatmap, reload_module
# ----> 3 reload_module('gpt_embeds')
#       4 from gpt_embeds import embeds, toks, enc
#       6 tok_start = 4000
#
# File ~/hierarchical_interp/hierarchical_interp/interp_utils/general_utils.py:43, in reload_module(module_name)
#      41     if x.split(".")[0] == module_name:
#      42         del sys.modules[x]
# ---> 43 module = __import__(module_name, fromlist=[""])
#      44 return module
#
# File ~/hierarchical_interp/hierarchical_interp/gpt_embeds/__init__.py:1
# ----> 1 from .embeds import embeds, toks, enc
#
# ModuleNotFoundError: No module named 'gpt_embeds.embeds'

# %%
mean_dir = embeds.mean(dim=0)
mean_dir = mean_dir.div(torch.norm(mean_dir))

# %%
from interp_utils import hist
proj_embeds = embeds @ mean_dir

hist(proj_embeds, info=all_toks)
