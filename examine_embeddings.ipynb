# %%
from transformers import GPT2LMHeadModel
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch.distributions as dists
import numpy as np

# %%
from interp_utils import heatmap, reload_module

reload_module('gpt_embeds')
from gpt_embeds import embeds, toks, enc

tok_start = 4000
n_toks = 300
embeds_subset = embeds[tok_start:tok_start+n_toks]
toks_subset = toks[tok_start:tok_start+n_toks]

heatmap(embeds_subset @ embeds_subset.T, info_0={'tok': toks_subset}, info_1={'tok': toks_subset})

# %%
mean_dir = embeds.mean(dim=0)
mean_dir = mean_dir.div(torch.norm(mean_dir))

# %%
from interp_utils import hist
proj_embeds = embeds @ mean_dir

hist(proj_embeds, info=all_toks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/noa/cloned/hierarchical_interp/examine_embeddings.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/home/noa/cloned/hierarchical_interp/examine_embeddings.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from interp_utils import hist
#       <a href='vscode-notebook-cell:/home/noa/cloned/hierarchical_interp/examine_embeddings.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> proj_embeds = embeds @ mean_dir
# ----> <a href='vscode-notebook-cell:/home/noa/cloned/hierarchical_interp/examine_embeddings.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> hist(proj_embeds, info=all_toks)
#
# NameError: name 'all_toks' is not defined
